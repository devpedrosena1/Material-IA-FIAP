# %%
#@title Código

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Código exemplo para a turma 1TDSQ

# %%
vetor = np.array([[1,2,3,4]])
matriz = np.array([[1,2,3],[4,5,6]])
matriz.shape
# Out:
# (2, 3)

# %%
dataset = pd.read_csv('gaf_esp.csv', sep=';')
display(dataset)
# Out:
#       Espécie  Comprimento do Abdômen  Comprimento das Antenas
# 0   Gafanhoto                    0.50                      7.0
# 1   Gafanhoto                    0.50                      6.0
# 2   Gafanhoto                    0.60                      5.5
# 3   Gafanhoto                    0.65                      4.5
# 4   Gafanhoto                    0.54                      3.2
# ..        ...                     ...                      ...
# 95  Esperança                    9.75                      6.2
# 96  Esperança                    6.20                      8.1
# 97  Esperança                    9.20                      4.7
# 98  Esperança                    9.10                      6.0
# 99  Esperança                    8.29                      7.0
#
# [100 rows x 3 columns]

# %%
dataset
# Out:
#       Espécie  Comprimento do Abdômen  Comprimento das Antenas
# 0   Gafanhoto                    0.50                      7.0
# 1   Gafanhoto                    0.50                      6.0
# 2   Gafanhoto                    0.60                      5.5
# 3   Gafanhoto                    0.65                      4.5
# 4   Gafanhoto                    0.54                      3.2
# ..        ...                     ...                      ...
# 95  Esperança                    9.75                      6.2
# 96  Esperança                    6.20                      8.1
# 97  Esperança                    9.20                      4.7
# 98  Esperança                    9.10                      6.0
# 99  Esperança                    8.29                      7.0
#
# [100 rows x 3 columns]

# %%
dataset_2 = pd.read_csv('mall.csv', sep=';')

# %%
##dataset.head(10) #-> pega a base dos 10 PRIMEIROS dados
##dataset.tail(10) #-> pega a base dos 10 ULTIMOS dados
dataset.describe()
# Out:
#        Comprimento do Abdômen  Comprimento das Antenas
# count              100.000000               100.000000
# mean                 4.936200                 5.382400
# std                  3.343806                 2.296001
# min                  0.500000                 0.890000
# 25%                  1.692500                 3.775000
# 50%                  4.500000                 5.500000
# 75%                  8.200000                 7.000000
# max                 10.000000                 9.700000

# %%
dados = {
    'nome' : ['Ana', 'João', 'Pedro'],
    'idade' : [25, 18, 29],
    'cidade' : ['SP', 'MG', 'RJ'],
    'salario' : [2500, 1000, 5000]
}

# %%
dados
# Out:
# {'nome': ['Ana', 'João', 'Pedro'],
#  'idade': [25, 18, 29],
#  'cidade': ['SP', 'MG', 'RJ'],
#  'salario': [2500, 1000, 5000]}

# %%
dataset_3 = pd.DataFrame(dados)
dataset_3.head()
# Out:
#     nome  idade cidade  salario
# 0    Ana     25     SP     2500
# 1   João     18     MG     1000
# 2  Pedro     29     RJ     5000

# %%
dataset_3['salario'].describe()
# Out:
# count       3.000000
# mean     2833.333333
# std      2020.725942
# min      1000.000000
# 25%      1750.000000
# 50%      2500.000000
# 75%      3750.000000
# max      5000.000000
# Name: salario, dtype: float64

# %%
numeros_randomicos = np.random.rand(15)
numeros_randomicos
# Out:
# array([0.53197744, 0.20857367, 0.09080516, 0.92336793, 0.30289398,
#        0.43056642, 0.5667669 , 0.43849207, 0.17656412, 0.04002651,
#        0.26240195, 0.23401557, 0.70256729, 0.2142325 , 0.60458638])

# %%
plt.plot(numeros_randomicos, label = 'analise financeira')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.legend()
## plt.show() -> para usar no vscode
plt.grid()

# %%
nomes = dataset_3['nome']
idades = dataset_3['idade']
salario = dataset_3['salario']

# %%
plt.scatter(idades, salario , label='idades x salarios')
plt.xlabel('idade')
plt.ylabel('salario')
plt.legend()
plt.grid()

# %%
dataset.columns = dataset.columns.str.strip()
print(dataset.columns)
plt.scatter(dataset['Comprimento das Antenas'], dataset['Comprimento do Abdômen'], label='Comprimento das antenas x Comprimento do abdômen')
plt.xlabel('Comprimento das antenas')
plt.ylabel('Comprimento do abdômen')
plt.legend()
plt.grid()
#plt.show() -> vscode
# Out:
# Index(['Espécie', 'Comprimento do Abdômen', 'Comprimento das Antenas'], dtype='object')

# %%
sns.pairplot(dataset_2)
